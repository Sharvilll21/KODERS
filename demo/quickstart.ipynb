# %%
---

## 2. `pyproject.toml`
This is your **project configuration file** (tells Python how to install your project).

### 👉 Create a file named:

# %%
from src.pipeline.pipeline import Pipeline

class DummyModel:
    def fit(self, X, y):
        pass

    def predict(self, X):
        return [0] * len(X)


pipeline = Pipeline([
    ("model", DummyModel())
])

pipeline.fit([[1], [2]], [1, 2])
print(pipeline.predict([[3], [4]]))
# Out:
# [0, 0]
